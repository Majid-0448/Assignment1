# %%
import pandas as pd

# %%
df = pd.read_csv("jsrt_metadata.csv")

# %%
df
# Out:
#          study_id  subtlety  size age  gender       x       y       state  \
# 0    JPCLN001.png       5.0  15.0  53    Male  1634.0   692.0   malignant
# 1    JPCLN002.png       5.0  30.0  78  Female  1614.0  1090.0      benign
# 2    JPCLN003.png       5.0  30.0  63  Female  1303.0   447.0   malignant
# 3    JPCLN004.png       5.0  14.0  68  Female   606.0   836.0      benign
# 4    JPCLN005.png       5.0  35.0  73  Female  1438.0   692.0   malignant
# ..            ...       ...   ...  ..     ...     ...     ...         ...
# 242  JPCNN089.png       NaN   NaN  50    Male     NaN     NaN  non-nodule
# 243  JPCNN090.png       NaN   NaN  68  Female     NaN     NaN  non-nodule
# 244  JPCNN091.png       NaN   NaN  81    Male     NaN     NaN  non-nodule
# 245  JPCNN092.png       NaN   NaN  70  Female     NaN     NaN  non-nodule
# 246  JPCNN093.png       NaN   NaN  41    Male     NaN     NaN  non-nodule
#
#                position           diagnosis
# ...

# %%
import numpy as np

# %%
df.isnull().sum()
# Out:
# study_id      0
# subtlety     93
# size         93
# age           0
# gender        0
# x            93
# y            93
# state         0
# position     93
# diagnosis    93
# dtype: int64

# %%
df["subtlety"]
# Out:
# 0      5.0
# 1      5.0
# 2      5.0
# 3      5.0
# 4      5.0
#       ...
# 242    NaN
# 243    NaN
# 244    NaN
# 245    NaN
# 246    NaN
# Name: subtlety, Length: 247, dtype: float64

# %%
m = df["subtlety"].astype("float").mean()

# %%
m=int(m)

# %%
df["subtlety"].replace(np.nan,m,inplace=True)

# %%
df.isnull().sum()
# Out:
# study_id      0
# subtlety      0
# size         93
# age           0
# gender        0
# x            93
# y            93
# state         0
# position     93
# diagnosis    93
# dtype: int64

# %%
df["x"]
# Out:
# 0      1634.0
# 1      1614.0
# 2      1303.0
# 3       606.0
# 4      1438.0
#         ...
# 242       NaN
# 243       NaN
# 244       NaN
# 245       NaN
# 246       NaN
# Name: x, Length: 247, dtype: float64

# %%
m = df["x"].astype("float").mean()

# %%
m="{:.1f}".format(m)

# %%
df["x"].replace(np.nan,m,inplace=True)

# %%
df.isnull().sum()
# Out:
# study_id      0
# subtlety      0
# size         93
# age           0
# gender        0
# x             0
# y            93
# state         0
# position     93
# diagnosis    93
# dtype: int64

# %%
m = df["size"].astype("float").mean()

# %%
m=int(m)

# %%
df["size"].replace(np.nan,m,inplace=True)

# %%
df["y"].replace(np.nan,m,inplace=True)

# %%
m="{:.1f}".format(m)

# %%
df["y"].replace(np.nan,m,inplace=True)

# %%
m = df["position"].value_counts().idxmax()

# %%
df["position"].replace(np.nan,m,inplace=True)

# %%
m = df["diagnosis"].value_counts().idxmax()

# %%
df["diagnosis"].replace(np.nan,m,inplace=True)

# %%
df.isnull().sum()
# Out:
# study_id     0
# subtlety     0
# size         0
# age          0
# gender       0
# x            0
# y            0
# state        0
# position     0
# diagnosis    0
# dtype: int64

# %%
import matplotlib as plt
from matplotlib import pyplot

# %%
plt.pyplot.hist(df["diagnosis"],color="red",ec="black")
# Out:
# (array([167.,  33.,  13.,   5.,   8.,   7.,   3.,   3.,   4.,   4.]),
#  array([ 0. ,  3.1,  6.2,  9.3, 12.4, 15.5, 18.6, 21.7, 24.8, 27.9, 31. ]),
#  <a list of 10 Patch objects>)

# %%
plt.pyplot.pie(df["diagnosis"].value_counts())
# Out:
# ([<matplotlib.patches.Wedge at 0x14f18739408>,
# ...
#  [Text(-0.35054586834727886, 1.042649315054996, ''),
#   Text(-0.647695063423749, -0.8890956668528455, ''),
#   Text(-0.17415030162497125, -1.0861269135989273, ''),
#   Text(0.1325904426548767, -1.0919797500487745, ''),
#   Text(0.33725646230925976, -1.047023437479144, ''),
#   Text(0.4799715744094368, -0.9897612276498441, ''),
#   Text(0.5780255148670865, -0.9358880831395597, ''),
#   Text(0.670100048440955, -0.8723336088214358, ''),
#   Text(0.7450098066787193, -0.8092962300372698, ''),
#   Text(0.7949362888017328, -0.7603132885502714, ''),
#   Text(0.8325727279525352, -0.7189037854050249, ''),
#   Text(0.8680546281712871, -0.6756338968038895, ''),
#   Text(0.9012901690886234, -0.6306155969401652, ''),
#   Text(0.9321933434832768, -0.5839653845609942, ''),
#   Text(0.960684179852312, -0.5358039814908906, ''),
#   Text(0.9866889493620762, -0.486256020226755, ''),
#   Text(1.010140356644312, -0.43544972141282023, ''),
# ...

# %%
df['diagnosis'].value_counts()
# Out:
# lung cancer                                       149
# lung cancer(adenocarcinoma)                        23
# tuberculoma                                        14
# granuloma                                           8
# lung cancer(bronchioloalveolar cell carcinoma)      7
# inflammatory mass                                   4
# unknown                                             4
# metastasis of colon cancer                          4
# pulmonary tuberculosis                              3
# pulmonary hematoma                                  2
# sclerosing hemangioma                               2
# hamartoma                                           2
# susp. inflammatory mass                             2
# lung abscess                                        2
# Cryptococcosis                                      2
# Inflammatory mass                                   2
# lung cancer(squamous cell carcinoma)                2
# ...

# %%
i=df.groupby(by="diagnosis")

# %%
i = i.get_group('lung cancer')

# %%
plt.pyplot.pie(i["gender"].value_counts(),labels=["male",'female'],autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x14f187fc348>,
# ...
#  [Text(-0.011596189353831868, 1.0999388748437207, 'male'),
#   Text(0.011596086370122407, -1.0999388759294295, 'female')],
#  [Text(-0.0063251941929992, 0.5999666590056658, '50.3%'),
#   Text(0.006325138020066767, -0.5999666595978705, '49.7%')])

# %%
i=df.groupby(by="diagnosis")
i = i.get_group('lung cancer(adenocarcinoma)')
plt.pyplot.pie(i["gender"].value_counts(),labels=["male",'female'],autopct='%1.1f%%',
               explode=[0,0.2],shadow=True)
# Out:
# ([<matplotlib.patches.Wedge at 0x14f18846f48>,
# ...
#  [Text(-0.5060716130681925, 0.9766737031611724, 'male'),
#   Text(0.5980847416947964, -1.1542506841028377, 'female')],
#  [Text(-0.2760390616735595, 0.5327311108151849, '65.2%'),
#   Text(0.3680521487352594, -0.710308113294054, '34.8%')])

# %%
i=df.groupby(by="diagnosis")
i = i.get_group('tuberculoma')
plt.pyplot.pie(i["gender"].value_counts(),labels=["male",'female'],autopct='%1.1f%%',
               explode=[0,0.2],shadow=True)
# Out:
# ([<matplotlib.patches.Wedge at 0x14f18898688>,
# ...
#  [Text(-0.47727208651780745, 0.9910657674599294, 'male'),
#   Text(0.5640488295210445, -1.171259543361735, 'female')],
#  [Text(-0.26033022900971314, 0.5405813277054159, '64.3%'),
#   Text(0.34710697201295043, -0.7207751036072215, '35.7%')])

# %%
i=df.groupby(by="diagnosis")
i = i.get_group('granuloma')
plt.pyplot.pie(i["gender"].value_counts(),labels=["male",'female'],autopct='%1.1f%%',
               explode=[0,0.2],shadow=True)
# Out:
# ([<matplotlib.patches.Wedge at 0x14f188dce88>,
# ...
#  [Text(-0.7778174593052023, 0.7778174593052024, 'male'),
#   Text(0.9192388155425116, -0.9192388155425121, 'female')],
#  [Text(-0.42426406871192845, 0.4242640687119285, '75.0%'),
#   Text(0.5656854249492379, -0.5656854249492381, '25.0%')])

# %%
i=df.groupby(by="diagnosis")
i = i.get_group('lung cancer(bronchioloalveolar cell carcinoma)')
plt.pyplot.pie(i["gender"].value_counts(),labels=["male",'female'],autopct='%1.1f%%',
               explode=[0,0.2],shadow=True)
# Out:
# ([<matplotlib.patches.Wedge at 0x14f1892e648>,
# ...
#  [Text(-0.24477311341532162, 1.0724206837565984, 'male'),
#   Text(0.2892774345176075, -1.2674062355373321, 'female')],
#  [Text(-0.13351260731744813, 0.5849567365945082, '57.1%'),
#   Text(0.1780168827800661, -0.7799422987922043, '42.9%')])

# %%
i=df.groupby(by="diagnosis")
i = i.get_group('unknown')
plt.pyplot.pie(i["gender"].value_counts(),labels=['female'],autopct='%1.1f%%',
               explode=[0],shadow=True)
# Out:
# ([<matplotlib.patches.Wedge at 0x14f1897c388>],
#  [Text(-1.1, 1.3471114790620887e-16, 'female')],
#  [Text(-0.6, 7.347880794884119e-17, '100.0%')])

# %%
i=df.groupby(by="diagnosis")
i = i.get_group('metastasis of colon cancer')
plt.pyplot.pie(i["gender"].value_counts(),labels=['male','female'],autopct='%1.1f%%',
               explode=[0,0.2],shadow=True)
# Out:
# ([<matplotlib.patches.Wedge at 0x14f189c0b48>,
# ...
#  [Text(-0.7778174593052023, 0.7778174593052024, 'male'),
#   Text(0.9192388155425116, -0.9192388155425121, 'female')],
#  [Text(-0.42426406871192845, 0.4242640687119285, '75.0%'),
#   Text(0.5656854249492379, -0.5656854249492381, '25.0%')])

# %%
i=df.groupby(by="diagnosis")
i = i.get_group('inflammatory mass')
plt.pyplot.pie(i["gender"].value_counts(),labels=['male','female'],autopct='%1.1f%%',
               explode=[0,0.2],shadow=True)
# Out:
# ([<matplotlib.patches.Wedge at 0x14f18a128c8>,
# ...
#  [Text(6.735557395310444e-17, 1.1, 'male'),
#   Text(-2.3880612583373386e-16, -1.3, 'female')],
#  [Text(3.6739403974420595e-17, 0.6, '50.0%'),
#   Text(-1.4695761589768238e-16, -0.8, '50.0%')])

# %%
i=df.groupby(by="diagnosis")
i = i.get_group('pulmonary tuberculosis')
plt.pyplot.pie(i["gender"].value_counts(),labels=['male'],autopct='%1.1f%%',explode=[0],shadow=True)
# Out:
# ([<matplotlib.patches.Wedge at 0x14f18a61548>],
#  [Text(-1.1, 1.3471114790620887e-16, 'male')],
#  [Text(-0.6, 7.347880794884119e-17, '100.0%')])

# %%
i=df.groupby(by="diagnosis")
i = i.get_group('lung abscess')
plt.pyplot.pie(i["gender"].value_counts(),labels=['male','female'],autopct='%1.1f%%',
               explode=[0,0.2],shadow=True)
# Out:
# ([<matplotlib.patches.Wedge at 0x14f19a79ec8>,
# ...
#  [Text(6.735557395310444e-17, 1.1, 'male'),
#   Text(-2.3880612583373386e-16, -1.3, 'female')],
#  [Text(3.6739403974420595e-17, 0.6, '50.0%'),
#   Text(-1.4695761589768238e-16, -0.8, '50.0%')])

# %%
i=df.groupby(by="diagnosis")
i = i.get_group('Cryptococcosis')
plt.pyplot.pie(i["gender"].value_counts(),labels=['female'],autopct='%1.1f%%',explode=[
    0.2],shadow=True)
# Out:
# ([<matplotlib.patches.Wedge at 0x14f19ac9b08>],
#  [Text(-1.3, 1.5920408388915593e-16, 'female')],
#  [Text(-0.8, 9.797174393178826e-17, '100.0%')])

# %%
i=df.groupby(by="diagnosis")
i = i.get_group('lung cancer(squamous cell carcinoma)')
plt.pyplot.pie(i["gender"].value_counts(),labels=['male'],autopct='%1.1f%%',explode=[
    0.2],shadow=True)
# Out:
# ([<matplotlib.patches.Wedge at 0x14f19b16408>],
#  [Text(-1.3, 1.5920408388915593e-16, 'male')],
#  [Text(-0.8, 9.797174393178826e-17, '100.0%')])

# %%
i=df.groupby(by="diagnosis")
i = i.get_group('Inflammatory mass')
plt.pyplot.pie(i["gender"].value_counts(),labels=['female'],autopct='%1.1f%%',
               explode=[0.2],shadow=True)
# Out:
# ([<matplotlib.patches.Wedge at 0x14f19b5acc8>],
#  [Text(-1.3, 1.5920408388915593e-16, 'female')],
#  [Text(-0.8, 9.797174393178826e-17, '100.0%')])

# %%
i=df.groupby(by="diagnosis")
i = i.get_group('pulmonary hematoma')
plt.pyplot.pie(i["gender"].value_counts(),labels=["male",'female'],autopct='%1.1f%%',
               explode=[0,0.2],shadow=True)
# Out:
# ([<matplotlib.patches.Wedge at 0x14f19ba5648>,
# ...
#  [Text(6.735557395310444e-17, 1.1, 'male'),
#   Text(-2.3880612583373386e-16, -1.3, 'female')],
#  [Text(3.6739403974420595e-17, 0.6, '50.0%'),
#   Text(-1.4695761589768238e-16, -0.8, '50.0%')])

# %%
i=df.groupby(by="diagnosis")
i = i.get_group('susp. inflammatory mass')
plt.pyplot.pie(i["gender"].value_counts(),labels=["male",'female'],autopct='%1.1f%%',
               explode=[0,0.2],shadow=True)
# Out:
# ([<matplotlib.patches.Wedge at 0x14f19bf5348>,
# ...
#  [Text(6.735557395310444e-17, 1.1, 'male'),
#   Text(-2.3880612583373386e-16, -1.3, 'female')],
#  [Text(3.6739403974420595e-17, 0.6, '50.0%'),
#   Text(-1.4695761589768238e-16, -0.8, '50.0%')])

# %%
i=df.groupby(by="diagnosis")
i = i.get_group('hamartoma')
plt.pyplot.pie(i["gender"].value_counts(),labels=['female'],autopct='%1.1f%%',
               explode=[0.2],shadow=True)
# Out:
# ([<matplotlib.patches.Wedge at 0x14f19c3cfc8>],
#  [Text(-1.3, 1.5920408388915593e-16, 'female')],
#  [Text(-0.8, 9.797174393178826e-17, '100.0%')])

# %%
i=df.groupby(by="diagnosis")
i = i.get_group('sclerosing hemangioma')
plt.pyplot.pie(i["gender"].value_counts(),labels=['female'],autopct='%1.1f%%',
               explode=[0.2],shadow=True)
# Out:
# ([<matplotlib.patches.Wedge at 0x14f19c8a8c8>],
#  [Text(-1.3, 1.5920408388915593e-16, 'female')],
#  [Text(-0.8, 9.797174393178826e-17, '100.0%')])

# %%
i=df.groupby(by="diagnosis")
i = i.get_group('lung cancer(large cell carcinoma)')
plt.pyplot.pie(i["gender"].value_counts(),labels=["male"],autopct='%1.1f%%',explode=[0.2],shadow=True)
# Out:
# ([<matplotlib.patches.Wedge at 0x14f19cd6188>],
#  [Text(-1.3, 1.5920408388915593e-16, 'male')],
#  [Text(-0.8, 9.797174393178826e-17, '100.0%')])

# %%
i=df.groupby(by="diagnosis")
i = i.get_group('susp. hamartoma')
plt.pyplot.pie(i["gender"].value_counts(),labels=["male"],autopct='%1.1f%%',explode=[0.2],shadow=True)
# Out:
# ([<matplotlib.patches.Wedge at 0x14f19d18a88>],
#  [Text(-1.3, 1.5920408388915593e-16, 'male')],
#  [Text(-0.8, 9.797174393178826e-17, '100.0%')])

# %%
i=df.groupby(by="diagnosis")
i = i.get_group('metastasis of uterine cancer')
plt.pyplot.pie(i["gender"].value_counts(),labels=['female'],autopct='%1.1f%%',
               explode=[0.2],shadow=True)
# Out:
# ([<matplotlib.patches.Wedge at 0x14f19d63388>],
#  [Text(-1.3, 1.5920408388915593e-16, 'female')],
#  [Text(-0.8, 9.797174393178826e-17, '100.0%')])

# %%
i=df.groupby(by="diagnosis")
i = i.get_group('organizing pneumonia')
plt.pyplot.pie(i["gender"].value_counts(),labels=['female'],autopct='%1.1f%%',
               explode=[0.2],shadow=True)
# Out:
# ([<matplotlib.patches.Wedge at 0x14f19da7c48>],
#  [Text(-1.3, 1.5920408388915593e-16, 'female')],
#  [Text(-0.8, 9.797174393178826e-17, '100.0%')])

# %%
i=df.groupby(by="diagnosis")
i = i.get_group('metastasis of ovarian cancer')
plt.pyplot.pie(i["gender"].value_counts(),labels=['female'],autopct='%1.1f%%',
               explode=[0.2],shadow=True)
# Out:
# ([<matplotlib.patches.Wedge at 0x14f19df1548>],
#  [Text(-1.3, 1.5920408388915593e-16, 'female')],
#  [Text(-0.8, 9.797174393178826e-17, '100.0%')])

# %%
i=df.groupby(by="diagnosis")
i = i.get_group('metastatic lung cancer')
plt.pyplot.pie(i["gender"].value_counts(),labels=['female'],autopct='%1.1f%%',
               explode=[0.2],shadow=True)
# Out:
# ([<matplotlib.patches.Wedge at 0x14f19e35e48>],
#  [Text(-1.3, 1.5920408388915593e-16, 'female')],
#  [Text(-0.8, 9.797174393178826e-17, '100.0%')])

# %%
i=df.groupby(by="diagnosis")
i = i.get_group('lung canceror metastasis')
plt.pyplot.pie(i["gender"].value_counts(),labels=['female'],autopct='%1.1f%%',
               explode=[0.2],shadow=True)
# Out:
# ([<matplotlib.patches.Wedge at 0x14f19e806c8>],
#  [Text(-1.3, 1.5920408388915593e-16, 'female')],
#  [Text(-0.8, 9.797174393178826e-17, '100.0%')])

# %%
i=df.groupby(by="diagnosis")
i = i.get_group('pneumonia')
plt.pyplot.pie(i["gender"].value_counts(),labels=['female'],autopct='%1.1f%%',
               explode=[0.2],shadow=True)
# Out:
# ([<matplotlib.patches.Wedge at 0x14f19ecb048>],
#  [Text(-1.3, 1.5920408388915593e-16, 'female')],
#  [Text(-0.8, 9.797174393178826e-17, '100.0%')])

# %%
i=df.groupby(by="diagnosis")
i = i.get_group('calcified granuloma')
plt.pyplot.pie(i["gender"].value_counts(),labels=["male"],autopct='%1.1f%%',explode=[0.2],shadow=True)
# Out:
# ([<matplotlib.patches.Wedge at 0x14f19f0c9c8>],
#  [Text(-1.3, 1.5920408388915593e-16, 'male')],
#  [Text(-0.8, 9.797174393178826e-17, '100.0%')])

# %%
i=df.groupby(by="diagnosis")
i = i.get_group('lung cancer(adenosquamous carcinoma)')
plt.pyplot.pie(i["gender"].value_counts(),labels=["male"],autopct='%1.1f%%',explode=[0.2],shadow=True)
# Out:
# ([<matplotlib.patches.Wedge at 0x14f19f5a1c8>],
#  [Text(-1.3, 1.5920408388915593e-16, 'male')],
#  [Text(-0.8, 9.797174393178826e-17, '100.0%')])

# %%
i=df.groupby(by="diagnosis")
i = i.get_group('lung cancer(small cell carcinoma)')
plt.pyplot.pie(i["gender"].value_counts(),labels=["male"],autopct='%1.1f%%',explode=[0.2],shadow=True)
# Out:
# ([<matplotlib.patches.Wedge at 0x14f19f9dac8>],
#  [Text(-1.3, 1.5920408388915593e-16, 'male')],
#  [Text(-0.8, 9.797174393178826e-17, '100.0%')])

# %%
i=df.groupby(by="diagnosis")
i = i.get_group('susp.tuberculoma')
plt.pyplot.pie(i["gender"].value_counts(),labels=["male"],autopct='%1.1f%%',explode=[0.2],shadow=True)
# Out:
# ([<matplotlib.patches.Wedge at 0x14f19fe8388>],
#  [Text(-1.3, 1.5920408388915593e-16, 'male')],
#  [Text(-0.8, 9.797174393178826e-17, '100.0%')])

# %%
i=df.groupby(by="diagnosis")
i = i.get_group('organiging pneumonia')
plt.pyplot.pie(i["gender"].value_counts(),labels=["male"],autopct='%1.1f%%',explode=[0.2],shadow=True)
# Out:
# ([<matplotlib.patches.Wedge at 0x14f1a02dc48>],
#  [Text(-1.3, 1.5920408388915593e-16, 'male')],
#  [Text(-0.8, 9.797174393178826e-17, '100.0%')])

# %%
i=df.groupby(by="diagnosis")
i = i.get_group('susp. sclerosing hemangioma')
plt.pyplot.pie(i["gender"].value_counts(),labels=['female'],autopct='%1.1f%%',
               explode=[0.2],shadow=True)
# Out:
# ([<matplotlib.patches.Wedge at 0x14f1a078508>],
#  [Text(-1.3, 1.5920408388915593e-16, 'female')],
#  [Text(-0.8, 9.797174393178826e-17, '100.0%')])

# %%
i=df.groupby(by="diagnosis")
i = i.get_group('susp. lung metastasis')
plt.pyplot.pie(i["gender"].value_counts(),labels=['female'],autopct='%1.1f%%',explode=[0.2],shadow=True)
# Out:
# ([<matplotlib.patches.Wedge at 0x14f1a0bbe08>],
#  [Text(-1.3, 1.5920408388915593e-16, 'female')],
#  [Text(-0.8, 9.797174393178826e-17, '100.0%')])
